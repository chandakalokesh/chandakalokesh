# %% [markdown]
# <a href="https://colab.research.google.com/github/chandakalokesh/chandakalokesh/blob/main/new__1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/208W5A0507/e-commerce Raw Data V1.csv')
data.head()
# Out:
#    RETAIL_YEAR  RETAIL_WEEK  CAL_YR  CAL_WK BYR_CNTRY_DESC  ITEM_ID  \
# 0         2022           18    2022      18  United States   897015
# 1         2022           18    2022      18  United States   377971
# 2         2022           18    2022      18  United States   214514
# 3         2022           18    2022      18  United States   164151
# 4         2022           18    2022      18  United States   435930
#
#    TRANSACTION_ID AUCT_END_DT  SLR_CNTRY_ID  BYR_CNTRY_ID  ...  PL_FLAG  \
# 0       559742871  14-07-2022             1             1  ...        1
# 1        19861469  06-07-2022             1             1  ...        1
# 2       444472702  23-07-2022             1             1  ...        1
# 3       160368271  28-07-2022             1             1  ...        1
# 4       278552060  28-07-2022             1             1  ...        1
#
#    CHECKOUT_STATUS PAYMENT_METHOD BIN_YN_ID SALE_TYPE START_PRICE_USD  \
# ...

# %%
print(data['CATEG_LVL4_NAME'].value_counts())
# Out:
# Trading Card Singles              636
# Exterior Parts & Accessories      246
# Books                             226
# Shirts                            185
# Vinyl Records                     155
#                                  ...
# Push-Pull Golf Cart Add-ons         1
# Playing Cards                       1
# Hammer Drills                       1
# Marine/Air Band Radio Antennas      1
# Vintage Cassette Decks              1
# Name: CATEG_LVL4_NAME, Length: 1751, dtype: int64

# %%
print(data['META_CATEG_NAME'].value_counts())
# Out:
# Clothing, Shoes & Accessories     1303
# eBay Motors                       1250
# Home & Garden                     1043
# Sports Mem, Cards & Fan Shop       940
# Collectibles                       765
# Toys & Hobbies                     549
# Health & Beauty                    510
# Sporting Goods                     422
# Business & Industrial              371
# Books & Magazines                  272
# Consumer Electronics               255
# Stamps                             253
# Computers/Tablets & Networking     246
# Music                              225
# Video Games & Consoles             221
# Cell Phones & Accessories          215
# Coins & Paper Money                212
# Jewelry & Watches                  211
# Movies & TV                        136
# Crafts                             129
# Musical Instruments & Gear          94
# Cameras & Photo                     71
# Pet Supplies                        57
# Pottery & Glass                     57
# ...

# %%
data.shape
# Out:
# (10000, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RETAIL_YEAR      10000 non-null  int64
#  1   RETAIL_WEEK      10000 non-null  int64
#  2   CAL_YR           10000 non-null  int64
#  3   CAL_WK           10000 non-null  int64
#  4   BYR_CNTRY_DESC   10000 non-null  object
#  5   ITEM_ID          10000 non-null  int64
#  6   TRANSACTION_ID   10000 non-null  int64
#  7   AUCT_END_DT      10000 non-null  object
#  8   SLR_CNTRY_ID     10000 non-null  int64
#  9   BYR_CNTRY_ID     10000 non-null  int64
#  10  BUYER_ID         10000 non-null  int64
#  11  LEAF_CATEG_ID    10000 non-null  int64
#  12  CREATED_DT       10000 non-null  object
#  13  BSNS_VRTCL_NAME  10000 non-null  object
#  14  META_CATEG_NAME  10000 non-null  object
#  15  USER_CRE_DATE    10000 non-null  object
#  16  CATEG_LVL2_NAME  10000 non-null  object
# ...

# %%
d=data.drop_duplicates()
d.shape
# Out:
# (10000, 29)

# %%
data.head()
# Out:
#    RETAIL_YEAR  RETAIL_WEEK  CAL_YR  CAL_WK BYR_CNTRY_DESC  ITEM_ID  \
# 0         2022           18    2022      18  United States   897015
# 1         2022           18    2022      18  United States   377971
# 2         2022           18    2022      18  United States   214514
# 3         2022           18    2022      18  United States   164151
# 4         2022           18    2022      18  United States   435930
#
#    TRANSACTION_ID AUCT_END_DT  SLR_CNTRY_ID  BYR_CNTRY_ID  ...  PL_FLAG  \
# 0       559742871  14-07-2022             1             1  ...        1
# 1        19861469  06-07-2022             1             1  ...        1
# 2       444472702  23-07-2022             1             1  ...        1
# 3       160368271  28-07-2022             1             1  ...        1
# 4       278552060  28-07-2022             1             1  ...        1
#
#    CHECKOUT_STATUS PAYMENT_METHOD BIN_YN_ID SALE_TYPE START_PRICE_USD  \
# ...

# %%
drop1=data.drop('RETAIL_YEAR',axis=1)
drop1.head()
# Out:
#    RETAIL_WEEK  CAL_YR  CAL_WK BYR_CNTRY_DESC  ITEM_ID  TRANSACTION_ID  \
# 0           18    2022      18  United States   897015       559742871
# 1           18    2022      18  United States   377971        19861469
# 2           18    2022      18  United States   214514       444472702
# 3           18    2022      18  United States   164151       160368271
# 4           18    2022      18  United States   435930       278552060
#
#   AUCT_END_DT  SLR_CNTRY_ID  BYR_CNTRY_ID  BUYER_ID  ...  PL_FLAG  \
# 0  14-07-2022             1             1     19029  ...        1
# 1  06-07-2022             1             1     19029  ...        1
# 2  23-07-2022             1             1     19029  ...        1
# 3  28-07-2022             1             1     19029  ...        1
# 4  28-07-2022             1             1     19029  ...        1
#
#   CHECKOUT_STATUS PAYMENT_METHOD BIN_YN_ID SALE_TYPE START_PRICE_USD  \
# ...

# %%
drop2=data.drop('RETAIL_WEEK',axis=1)
drop2.head()
# Out:
#    RETAIL_YEAR  CAL_YR  CAL_WK BYR_CNTRY_DESC  ITEM_ID  TRANSACTION_ID  \
# 0         2022    2022      18  United States   897015       559742871
# 1         2022    2022      18  United States   377971        19861469
# 2         2022    2022      18  United States   214514       444472702
# 3         2022    2022      18  United States   164151       160368271
# 4         2022    2022      18  United States   435930       278552060
#
#   AUCT_END_DT  SLR_CNTRY_ID  BYR_CNTRY_ID  BUYER_ID  ...  PL_FLAG  \
# 0  14-07-2022             1             1     19029  ...        1
# 1  06-07-2022             1             1     19029  ...        1
# 2  23-07-2022             1             1     19029  ...        1
# 3  28-07-2022             1             1     19029  ...        1
# 4  28-07-2022             1             1     19029  ...        1
#
#   CHECKOUT_STATUS PAYMENT_METHOD BIN_YN_ID SALE_TYPE START_PRICE_USD  \
# ...

# %%
import seaborn as sns
plt.subplots(figsize=(15,7))
ax=sns.swarmplot(x='QUANTITY',y='GMB',data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
data[data['META_CATEG_NAME']=='Books & Magazines']['QUANTITY'].count()
# Out:
# 272

# %%
temp=data.groupby('META_CATEG_NAME').sum()['QUANTITY']
type(temp)
temp
# Out:
# META_CATEG_NAME
# Antiques                            34
# Art                                 38
# Baby                                11
# Books & Magazines                  278
# Business & Industrial              569
# Cameras & Photo                     80
# Cell Phones & Accessories          252
# Clothing, Shoes & Accessories     1363
# Coins & Paper Money                243
# Collectibles                       799
# Computers/Tablets & Networking     286
# Consumer Electronics               479
# Crafts                             134
# Dolls & Bears                       24
# Entertainment Memorabilia           50
# Everything Else                      5
# Gift Cards & Coupons                 2
# Health & Beauty                    597
# Home & Garden                     1216
# Jewelry & Watches                  288
# Movies & TV                        137
# Music                              225
# Musical Instruments & Gear          99
# ...

# %%
gfg=pd.Series(temp)
gfg.plot.bar()
plt.show()

# %%
temp3=data[data['META_CATEG_NAME']=='eBay Motors']['BYR_CNTRY_DESC']
temp3.value_counts()
# Out:
# United States     1194
# Canada              15
# Japan               13
# Germany              5
# Korea, South         3
# Puerto Rico          3
# Mexico               3
# United Kingdom       2
# Italy                2
# New Zealand          2
# APO/FPO              1
# Australia            1
# Spain                1
# Finland              1
# Guatemala            1
# Sweden               1
# Greece               1
# Vietnam              1
# Name: BYR_CNTRY_DESC, dtype: int64

# %%
data.groupby('BYR_CNTRY_DESC')

# %%
data['year']=data['USER_CRE_DATE'].apply(lambda x: x.split(' ')[0].split('-')[2])
data.groupby('year').sum()
# Out:
#       RETAIL_YEAR  RETAIL_WEEK   CAL_YR  CAL_WK    ITEM_ID  TRANSACTION_ID  \
# year
# 1996         2022           18     2022      18     111604       395958839
# 1997        78858          756    78858     747   20183947     19115610386
# 1998       580314         5634   580314    5586  155432281    139500586033
# 1999      1714656        16800  1714656   16636  441932867    422772844019
# 2000      2135232        20884  2135232   20702  546678279    540034394360
# 2001      1914834        18686  1914834   18513  493005299    477466667149
# 2002      1935054        18866  1935054   18667  482967542    503874501598
# 2003      2345520        22901  2345520   22664  598367844    560925312597
# 2004      1916856        18791  1916856   18611  478726589    468475573374
# 2005      2509302        24518  2509302   24301  644782326    638044996895
# 2006      2412246        23440  2412246   23262  588797455    593492287044
# ...

# %%
year=data['year'].unique()
temp1=data['year'].value_counts()

plt.bar(year,temp1)
plt.xlabel('year')
plt.ylabel('no user created')
plt.xticks(year,rotation='vertical',size=8)
plt.show()
